# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/Users/lamiaebenouahi/Desktop/Portfolio/GitHub/lemongrass-regression-student-code/week_05_explanatory_da/weekly_project/muesli_orders.csv.xls',parse_dates=['Order Date'], header=1)
# Out:
# /var/folders/kn/69gx8nmx0z3b3y98m_v_21tr0000gn/T/ipykernel_26581/2783041826.py:1: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df = pd.read_csv('/Users/lamiaebenouahi/Desktop/Portfolio/GitHub/lemongrass-regression-student-code/week_05_explanatory_da/weekly_project/muesli_orders.csv.xls',parse_dates=['Order Date'], header=1)

# %%
df
# Out:
#       Index        Order ID Order Date       Ship Mode Customer ID  \
# 0        27  CA-2019-121755 2019-01-16    Second Class    EH-13945
# 1        45  CA-2019-118255 2019-03-11     First Class    ON-18715
# 2        48  CA-2019-169194 2019-06-20  Standard Class    LH-16900
# 3        60  CA-2019-111682 2019-06-17     First Class    TB-21055
# 4        63  CA-2018-135545 2018-11-24  Standard Class    KM-16720
# ...     ...             ...        ...             ...         ...
# 9989   9894  US-2019-115441 2019-07-25    Second Class    SH-19975
# 9990   9908  US-2018-129007 2018-09-13     First Class    KD-16615
# 9991   9913  CA-2018-132388 2018-10-10     First Class    KN-16390
# 9992   9920  CA-2019-149272 2019-03-15  Standard Class    MY-18295
# 9993   9948  CA-2020-121559 2020-06-01    Second Class    HW-14935
#
#           Customer Name Origin Channel Country/Region           City  \
# 0         Eric Hoffmann          Email  United States    Los Angeles
# 1         Odella Nelson          Sales  United States          Eagan
# 2        Lena Hernandez          Email  United States          Dover
# 3       Ted Butterfield          Email  United States           Troy
# 4          Kunst Miller          Email  United States    Los Angeles
# ...                 ...            ...            ...            ...
# 9989      Sally Hughsby          Sales  United States      Milwaukee
# 9990           Ken Dana          Sales  United States        Anaheim
# 9991  Katherine Nockton          Sales  United States  Santa Barbara
# 9992    Muhammed Yedwab          Sales  United States          Bryan
# 9993    Helen Wasserman          Sales  United States   Indianapolis
#
#            State  Postal Code   Region                 Category Sub-Category  \
# 0     California      90049.0     West  Special Projects Muesil  Gluten Free
# 1      Minnesota      55122.0  Central  Special Projects Muesil  Gluten Free
# 2       Delaware      19901.0     East  Special Projects Muesil  Gluten Free
# 3       New York      12180.0     East  Special Projects Muesil  Gluten Free
# 4     California      90004.0     West  Special Projects Muesil  Gluten Free
# ...          ...          ...      ...                      ...          ...
# 9989   Wisconsin      53209.0  Central           Toasted Muesli    With Nuts
# 9990  California      92804.0     West           Toasted Muesli    With Nuts
# 9991  California      93101.0     West           Toasted Muesli    With Nuts
# 9992       Texas      77803.0  Central           Toasted Muesli    With Nuts
# 9993     Indiana      46203.0  Central           Toasted Muesli    With Nuts
#
#            Product ID     Sales  Quantity  Discount    Profit
# 0     TEC-AC-10003027    90.570         3       0.0   11.7741
# 1     TEC-AC-10000171    45.980         2       0.0   19.7714
# 2     TEC-AC-10002167    45.000         3       0.0    4.9500
# 3     TEC-AC-10002167    30.000         2       0.0    3.3000
# 4     TEC-AC-10004633    13.980         2       0.0    6.1512
# ...               ...       ...       ...       ...       ...
# 9989  FUR-CH-10004626   403.560         4       0.0   96.8544
# 9990  FUR-CH-10000155   717.720         3       0.2   71.7720
# 9991  FUR-CH-10001714   362.136         3       0.2  -54.3204
# 9992  FUR-CH-10000863   528.430         5       0.3 -143.4310
# 9993  FUR-CH-10003746  1925.880         6       0.0  539.2464
#
# [9994 rows x 19 columns]

# %%
df
# Out:
#       Index        Order ID Order Date       Ship Mode Customer ID  \
# 0        27  CA-2019-121755 2019-01-16    Second Class    EH-13945
# 1        45  CA-2019-118255 2019-03-11     First Class    ON-18715
# 2        48  CA-2019-169194 2019-06-20  Standard Class    LH-16900
# 3        60  CA-2019-111682 2019-06-17     First Class    TB-21055
# 4        63  CA-2018-135545 2018-11-24  Standard Class    KM-16720
# ...     ...             ...        ...             ...         ...
# 9989   9894  US-2019-115441 2019-07-25    Second Class    SH-19975
# 9990   9908  US-2018-129007 2018-09-13     First Class    KD-16615
# 9991   9913  CA-2018-132388 2018-10-10     First Class    KN-16390
# 9992   9920  CA-2019-149272 2019-03-15  Standard Class    MY-18295
# 9993   9948  CA-2020-121559 2020-06-01    Second Class    HW-14935
#
#           Customer Name Origin Channel Country/Region           City  \
# 0         Eric Hoffmann          Email  United States    Los Angeles
# 1         Odella Nelson          Sales  United States          Eagan
# 2        Lena Hernandez          Email  United States          Dover
# 3       Ted Butterfield          Email  United States           Troy
# 4          Kunst Miller          Email  United States    Los Angeles
# ...                 ...            ...            ...            ...
# 9989      Sally Hughsby          Sales  United States      Milwaukee
# 9990           Ken Dana          Sales  United States        Anaheim
# 9991  Katherine Nockton          Sales  United States  Santa Barbara
# 9992    Muhammed Yedwab          Sales  United States          Bryan
# 9993    Helen Wasserman          Sales  United States   Indianapolis
#
#            State  Postal Code   Region                 Category Sub-Category  \
# 0     California      90049.0     West  Special Projects Muesil  Gluten Free
# 1      Minnesota      55122.0  Central  Special Projects Muesil  Gluten Free
# 2       Delaware      19901.0     East  Special Projects Muesil  Gluten Free
# 3       New York      12180.0     East  Special Projects Muesil  Gluten Free
# 4     California      90004.0     West  Special Projects Muesil  Gluten Free
# ...          ...          ...      ...                      ...          ...
# 9989   Wisconsin      53209.0  Central           Toasted Muesli    With Nuts
# 9990  California      92804.0     West           Toasted Muesli    With Nuts
# 9991  California      93101.0     West           Toasted Muesli    With Nuts
# 9992       Texas      77803.0  Central           Toasted Muesli    With Nuts
# 9993     Indiana      46203.0  Central           Toasted Muesli    With Nuts
#
#            Product ID     Sales  Quantity  Discount    Profit
# 0     TEC-AC-10003027    90.570         3       0.0   11.7741
# 1     TEC-AC-10000171    45.980         2       0.0   19.7714
# 2     TEC-AC-10002167    45.000         3       0.0    4.9500
# 3     TEC-AC-10002167    30.000         2       0.0    3.3000
# 4     TEC-AC-10004633    13.980         2       0.0    6.1512
# ...               ...       ...       ...       ...       ...
# 9989  FUR-CH-10004626   403.560         4       0.0   96.8544
# 9990  FUR-CH-10000155   717.720         3       0.2   71.7720
# 9991  FUR-CH-10001714   362.136         3       0.2  -54.3204
# 9992  FUR-CH-10000863   528.430         5       0.3 -143.4310
# 9993  FUR-CH-10003746  1925.880         6       0.0  539.2464
#
# [9994 rows x 19 columns]

# %%
#Change the column name to facilitate further analysis
df.columns= ['index', 'order_id', 'order_date', 'ship_mode', 'customer_id', 'customer_name', 'orign_channel', 'country', 'city', 'state', 'postal_code', 'region', 'category', 'sub_category', 'product_id', 'sales', 'quantity', 'discount', 'profit']

# %%
df
# Out:
#       index        order_id order_date       ship_mode customer_id  \
# 0        27  CA-2019-121755 2019-01-16    Second Class    EH-13945
# 1        45  CA-2019-118255 2019-03-11     First Class    ON-18715
# 2        48  CA-2019-169194 2019-06-20  Standard Class    LH-16900
# 3        60  CA-2019-111682 2019-06-17     First Class    TB-21055
# 4        63  CA-2018-135545 2018-11-24  Standard Class    KM-16720
# ...     ...             ...        ...             ...         ...
# 9989   9894  US-2019-115441 2019-07-25    Second Class    SH-19975
# 9990   9908  US-2018-129007 2018-09-13     First Class    KD-16615
# 9991   9913  CA-2018-132388 2018-10-10     First Class    KN-16390
# 9992   9920  CA-2019-149272 2019-03-15  Standard Class    MY-18295
# 9993   9948  CA-2020-121559 2020-06-01    Second Class    HW-14935
#
#           customer_name orign_channel        country           city  \
# 0         Eric Hoffmann         Email  United States    Los Angeles
# 1         Odella Nelson         Sales  United States          Eagan
# 2        Lena Hernandez         Email  United States          Dover
# 3       Ted Butterfield         Email  United States           Troy
# 4          Kunst Miller         Email  United States    Los Angeles
# ...                 ...           ...            ...            ...
# 9989      Sally Hughsby         Sales  United States      Milwaukee
# 9990           Ken Dana         Sales  United States        Anaheim
# 9991  Katherine Nockton         Sales  United States  Santa Barbara
# 9992    Muhammed Yedwab         Sales  United States          Bryan
# 9993    Helen Wasserman         Sales  United States   Indianapolis
#
#            state  postal_code   region                 category sub_category  \
# 0     California      90049.0     West  Special Projects Muesil  Gluten Free
# 1      Minnesota      55122.0  Central  Special Projects Muesil  Gluten Free
# 2       Delaware      19901.0     East  Special Projects Muesil  Gluten Free
# 3       New York      12180.0     East  Special Projects Muesil  Gluten Free
# 4     California      90004.0     West  Special Projects Muesil  Gluten Free
# ...          ...          ...      ...                      ...          ...
# 9989   Wisconsin      53209.0  Central           Toasted Muesli    With Nuts
# 9990  California      92804.0     West           Toasted Muesli    With Nuts
# 9991  California      93101.0     West           Toasted Muesli    With Nuts
# 9992       Texas      77803.0  Central           Toasted Muesli    With Nuts
# 9993     Indiana      46203.0  Central           Toasted Muesli    With Nuts
#
#            product_id     sales  quantity  discount    profit
# 0     TEC-AC-10003027    90.570         3       0.0   11.7741
# 1     TEC-AC-10000171    45.980         2       0.0   19.7714
# 2     TEC-AC-10002167    45.000         3       0.0    4.9500
# 3     TEC-AC-10002167    30.000         2       0.0    3.3000
# 4     TEC-AC-10004633    13.980         2       0.0    6.1512
# ...               ...       ...       ...       ...       ...
# 9989  FUR-CH-10004626   403.560         4       0.0   96.8544
# 9990  FUR-CH-10000155   717.720         3       0.2   71.7720
# 9991  FUR-CH-10001714   362.136         3       0.2  -54.3204
# 9992  FUR-CH-10000863   528.430         5       0.3 -143.4310
# 9993  FUR-CH-10003746  1925.880         6       0.0  539.2464
#
# [9994 rows x 19 columns]

# %%
#Make sure that there are missing values in the data
df = df.dropna(inplace=True)

# %%
#Extract features like month, day, etc. from the Order Date datetime column into their own columns

# %%
df['order_date'] = pd.to_datetime(df['order_date'])

# %%
df['month'] = df['order_date'].dt.month
df['weekday'] = df['order_date'].dt.weekday
df['day'] = df['order_date'].dt.day
df['year'] = df['order_date'].dt.year
df
# Out:
#       index        order_id order_date       ship_mode customer_id  \
# 0        27  CA-2019-121755 2019-01-16    Second Class    EH-13945
# 1        45  CA-2019-118255 2019-03-11     First Class    ON-18715
# 2        48  CA-2019-169194 2019-06-20  Standard Class    LH-16900
# 3        60  CA-2019-111682 2019-06-17     First Class    TB-21055
# 4        63  CA-2018-135545 2018-11-24  Standard Class    KM-16720
# ...     ...             ...        ...             ...         ...
# 9989   9894  US-2019-115441 2019-07-25    Second Class    SH-19975
# 9990   9908  US-2018-129007 2018-09-13     First Class    KD-16615
# 9991   9913  CA-2018-132388 2018-10-10     First Class    KN-16390
# 9992   9920  CA-2019-149272 2019-03-15  Standard Class    MY-18295
# 9993   9948  CA-2020-121559 2020-06-01    Second Class    HW-14935
#
#           customer_name orign_channel        country           city  \
# 0         Eric Hoffmann         Email  United States    Los Angeles
# 1         Odella Nelson         Sales  United States          Eagan
# 2        Lena Hernandez         Email  United States          Dover
# 3       Ted Butterfield         Email  United States           Troy
# 4          Kunst Miller         Email  United States    Los Angeles
# ...                 ...           ...            ...            ...
# 9989      Sally Hughsby         Sales  United States      Milwaukee
# 9990           Ken Dana         Sales  United States        Anaheim
# 9991  Katherine Nockton         Sales  United States  Santa Barbara
# 9992    Muhammed Yedwab         Sales  United States          Bryan
# 9993    Helen Wasserman         Sales  United States   Indianapolis
#
#            state  ...  sub_category       product_id     sales quantity  \
# 0     California  ...   Gluten Free  TEC-AC-10003027    90.570        3
# 1      Minnesota  ...   Gluten Free  TEC-AC-10000171    45.980        2
# 2       Delaware  ...   Gluten Free  TEC-AC-10002167    45.000        3
# 3       New York  ...   Gluten Free  TEC-AC-10002167    30.000        2
# 4     California  ...   Gluten Free  TEC-AC-10004633    13.980        2
# ...          ...  ...           ...              ...       ...      ...
# 9989   Wisconsin  ...     With Nuts  FUR-CH-10004626   403.560        4
# 9990  California  ...     With Nuts  FUR-CH-10000155   717.720        3
# 9991  California  ...     With Nuts  FUR-CH-10001714   362.136        3
# 9992       Texas  ...     With Nuts  FUR-CH-10000863   528.430        5
# 9993     Indiana  ...     With Nuts  FUR-CH-10003746  1925.880        6
#
#      discount    profit  month  weekday  day  year
# 0         0.0   11.7741      1        2   16  2019
# 1         0.0   19.7714      3        0   11  2019
# 2         0.0    4.9500      6        3   20  2019
# 3         0.0    3.3000      6        0   17  2019
# 4         0.0    6.1512     11        5   24  2018
# ...       ...       ...    ...      ...  ...   ...
# 9989      0.0   96.8544      7        3   25  2019
# 9990      0.2   71.7720      9        3   13  2018
# 9991      0.2  -54.3204     10        2   10  2018
# 9992      0.3 -143.4310      3        4   15  2019
# 9993      0.0  539.2464      6        0    1  2020
#
# [9994 rows x 23 columns]

# %%
#Plot small sections of the order date over time (1 week, 1 month, etc.)

# %%
df_one_week = df[(df['order_date'] >= '2018-07-02') & (df['order_date'] < '2018-07-09')]
df_one_week.set_index('order_date', inplace=True)
df_one_week.plot( y='sales')
plt.title('Sales for Week X')
plt.xlabel('Order Date')
plt.ylabel('Sales')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 6))  # Set the size of the figure
df_one_month.plot(kind='bar', y='sales', color='teal', ax=ax)

# Adding title and labels with custom settings
plt.title('Sales for July 2018', fontsize=16, fontweight='bold')
plt.xlabel('Order Date', fontsize=12)
plt.ylabel('Sales', fontsize=12)

ax.set_xticklabels([])  
plt.xticks(rotation=45, ha='right', fontsize=10)  # Adjust alignment and font size


plt.tight_layout()


ax.grid(True, which='both', linestyle='--', linewidth=0.5, color='gray', alpha=0.7)

# %%
#Plot the number of orders per weekday
orders_weekly = df['weekday'].value_counts()
orders_weekly.plot(kind= 'bar', figsize=(10,8), color='olive')
plt.title('Orders per week')
plt.xlabel('Weekday')
plt.ylabel('Num of orders');

# %%
#Merge all datasets together:

# %%
df_orders = pd.read_csv('/Users/lamiaebenouahi/Desktop/Spiced Bootcamp/GitHub/lemongrass-regression-student-code/week_05_explanatory_da/data/muesli_orders_clean.csv', parse_dates= ['order_date'])
df_orders.set_index('order_id', inplace=True)
df_orders
# Out:
#                 Unnamed: 0  index order_date       ship_mode customer_id  \
# order_id
# CA-2019-121755           0     27 2019-01-16    Second Class    EH-13945
# CA-2019-118255           1     45 2019-03-11     First Class    ON-18715
# CA-2019-169194           2     48 2019-06-20  Standard Class    LH-16900
# CA-2019-111682           3     60 2019-06-17     First Class    TB-21055
# CA-2018-135545           4     63 2018-11-24  Standard Class    KM-16720
# ...                    ...    ...        ...             ...         ...
# US-2019-115441        9989   9894 2019-07-25    Second Class    SH-19975
# US-2018-129007        9990   9908 2018-09-13     First Class    KD-16615
# CA-2018-132388        9991   9913 2018-10-10     First Class    KN-16390
# CA-2019-149272        9992   9920 2019-03-15  Standard Class    MY-18295
# CA-2020-121559        9993   9948 2020-06-01    Second Class    HW-14935
#
#                     customer_name origin_channel country/region  \
# order_id
# CA-2019-121755      Eric Hoffmann          Email  United States
# CA-2019-118255      Odella Nelson          Sales  United States
# CA-2019-169194     Lena Hernandez          Email  United States
# CA-2019-111682    Ted Butterfield          Email  United States
# CA-2018-135545       Kunst Miller          Email  United States
# ...                           ...            ...            ...
# US-2019-115441      Sally Hughsby          Sales  United States
# US-2018-129007           Ken Dana          Sales  United States
# CA-2018-132388  Katherine Nockton          Sales  United States
# CA-2019-149272    Muhammed Yedwab          Sales  United States
# CA-2020-121559    Helen Wasserman          Sales  United States
#
#                          city       state  ...  sub-category       product_id  \
# order_id                                   ...
# CA-2019-121755    Los Angeles  California  ...   Gluten Free  TEC-AC-10003027
# CA-2019-118255          Eagan   Minnesota  ...   Gluten Free  TEC-AC-10000171
# CA-2019-169194          Dover    Delaware  ...   Gluten Free  TEC-AC-10002167
# CA-2019-111682           Troy    New York  ...   Gluten Free  TEC-AC-10002167
# CA-2018-135545    Los Angeles  California  ...   Gluten Free  TEC-AC-10004633
# ...                       ...         ...  ...           ...              ...
# US-2019-115441      Milwaukee   Wisconsin  ...     With Nuts  FUR-CH-10004626
# US-2018-129007        Anaheim  California  ...     With Nuts  FUR-CH-10000155
# CA-2018-132388  Santa Barbara  California  ...     With Nuts  FUR-CH-10001714
# CA-2019-149272          Bryan       Texas  ...     With Nuts  FUR-CH-10000863
# CA-2020-121559   Indianapolis     Indiana  ...     With Nuts  FUR-CH-10003746
#
#                    sales quantity discount    profit  month  day  weekday  \
# order_id
# CA-2019-121755    90.570        3      0.0   11.7741      1   16        2
# CA-2019-118255    45.980        2      0.0   19.7714      3   11        0
# CA-2019-169194    45.000        3      0.0    4.9500      6   20        3
# CA-2019-111682    30.000        2      0.0    3.3000      6   17        0
# CA-2018-135545    13.980        2      0.0    6.1512     11   24        5
# ...                  ...      ...      ...       ...    ...  ...      ...
# US-2019-115441   403.560        4      0.0   96.8544      7   25        3
# US-2018-129007   717.720        3      0.2   71.7720      9   13        3
# CA-2018-132388   362.136        3      0.2  -54.3204     10   10        2
# CA-2019-149272   528.430        5      0.3 -143.4310      3   15        4
# CA-2020-121559  1925.880        6      0.0  539.2464      6    1        0
#
#                 year
# order_id
# CA-2019-121755  2019
# CA-2019-118255  2019
# CA-2019-169194  2019
# CA-2019-111682  2019
# CA-2018-135545  2018
# ...              ...
# US-2019-115441  2019
# US-2018-129007  2018
# CA-2018-132388  2018
# CA-2019-149272  2019
# CA-2020-121559  2020
#
# [9994 rows x 23 columns]

# %%
df_campaign = pd.read_csv('/Users/lamiaebenouahi/Desktop/Spiced Bootcamp/GitHub/lemongrass-regression-student-code/week_05_explanatory_da/data/muesli_campaign_data.csv', parse_dates= ['Arrival Scan Date'])
df_campaign
# Out:
#            Order ID Arrival Scan Date     Customer Name
# 0    CA-2019-109666        03/05/2019      Kunst Miller
# 1    CA-2019-138933        03/05/2019       Jack Lebron
# 2    CA-2019-130001        03/05/2019  Heather Kirkland
# 3    CA-2019-113061        06/05/2019         Ed Ludwig
# 4    CA-2019-162138        06/05/2019       Grace Kelly
# ..              ...               ...               ...
# 328  CA-2020-129707        08/05/2020      Larry Hughes
# 329  CA-2020-125381        08/05/2020  Speros Goranitis
# 330  CA-2020-141733        15/05/2020       Rick Wilson
# 331  US-2020-104451        15/05/2020    Michelle Moray
# 332  US-2020-139647        15/05/2020      Todd Sumrall
#
# [333 rows x 3 columns]

# %%
df_campaign.columns = df_campaign.columns.str.lower().str.replace(' ', '_')
df_campaign
# Out:
#            order_id arrival_scan_date     customer_name
# 0    CA-2019-109666        03/05/2019      Kunst Miller
# 1    CA-2019-138933        03/05/2019       Jack Lebron
# 2    CA-2019-130001        03/05/2019  Heather Kirkland
# 3    CA-2019-113061        06/05/2019         Ed Ludwig
# 4    CA-2019-162138        06/05/2019       Grace Kelly
# ..              ...               ...               ...
# 328  CA-2020-129707        08/05/2020      Larry Hughes
# 329  CA-2020-125381        08/05/2020  Speros Goranitis
# 330  CA-2020-141733        15/05/2020       Rick Wilson
# 331  US-2020-104451        15/05/2020    Michelle Moray
# 332  US-2020-139647        15/05/2020      Todd Sumrall
#
# [333 rows x 3 columns]

# %%
df_campaign.set_index('order_id', inplace=True)
df_campaign
# Out:
#                arrival_scan_date     customer_name
# order_id
# CA-2019-109666        03/05/2019      Kunst Miller
# CA-2019-138933        03/05/2019       Jack Lebron
# CA-2019-130001        03/05/2019  Heather Kirkland
# CA-2019-113061        06/05/2019         Ed Ludwig
# CA-2019-162138        06/05/2019       Grace Kelly
# ...                          ...               ...
# CA-2020-129707        08/05/2020      Larry Hughes
# CA-2020-125381        08/05/2020  Speros Goranitis
# CA-2020-141733        15/05/2020       Rick Wilson
# US-2020-104451        15/05/2020    Michelle Moray
# US-2020-139647        15/05/2020      Todd Sumrall
#
# [333 rows x 2 columns]

# %%
df_intern = pd.read_csv('/Users/lamiaebenouahi/Desktop/Spiced Bootcamp/GitHub/lemongrass-regression-student-code/week_05_explanatory_da/data/muesli_Intern_data_study.csv', parse_dates= ['Ready to Ship Date'])
df_intern
# Out:
#            Order ID Ready to Ship Date Pickup Date
# 0    CA-2019-116540         02/09/2019  03/09/2019
# 1    CA-2019-116540         02/09/2019  03/09/2019
# 2    CA-2019-129847         04/09/2019  04/09/2019
# 3    CA-2019-129630         04/09/2019  04/09/2019
# 4    CA-2019-106278         05/09/2019  06/09/2019
# ..              ...                ...         ...
# 285  CA-2020-105333         04/12/2020  07/12/2020
# 286  CA-2020-105333         04/12/2020  07/12/2020
# 287  US-2020-110576         04/12/2020  07/12/2020
# 288  CA-2020-119305         04/12/2020  07/12/2020
# 289  CA-2020-142090         07/12/2020  09/12/2020
#
# [290 rows x 3 columns]

# %%
df_intern.columns = df_intern.columns.str.lower().str.replace(' ', '_')
df_intern
# Out:
#            order_id ready_to_ship_date pickup_date
# 0    CA-2019-116540         02/09/2019  03/09/2019
# 1    CA-2019-116540         02/09/2019  03/09/2019
# 2    CA-2019-129847         04/09/2019  04/09/2019
# 3    CA-2019-129630         04/09/2019  04/09/2019
# 4    CA-2019-106278         05/09/2019  06/09/2019
# ..              ...                ...         ...
# 285  CA-2020-105333         04/12/2020  07/12/2020
# 286  CA-2020-105333         04/12/2020  07/12/2020
# 287  US-2020-110576         04/12/2020  07/12/2020
# 288  CA-2020-119305         04/12/2020  07/12/2020
# 289  CA-2020-142090         07/12/2020  09/12/2020
#
# [290 rows x 3 columns]

# %%
df_process = pd.read_csv('/Users/lamiaebenouahi/Desktop/Spiced Bootcamp/GitHub/lemongrass-regression-student-code/week_05_explanatory_da/data/muesli_order_process_data.csv',parse_dates= ['On Truck Scan Date'])
df_process
# Out:
#       Row ID        Order ID  Order Date On Truck Scan Date  \
# 0       3074  CA-2019-125206    3/1/2019         07/01/2019
# 1       4919  CA-2019-160304    2/1/2019         09/01/2019
# 2       4920  CA-2019-160304    2/1/2019         09/01/2019
# 3       8604  US-2019-116365    3/1/2019         09/01/2019
# 4       8605  US-2019-116365    3/1/2019         09/01/2019
# ...      ...             ...         ...                ...
# 5894     908  CA-2020-143259  30/12/2020         06/01/2021
# 5895     909  CA-2020-143259  30/12/2020         06/01/2021
# 5896    1297  CA-2020-115427  30/12/2020         06/01/2021
# 5897    1298  CA-2020-115427  30/12/2020         06/01/2021
# 5898    5092  CA-2020-156720  30/12/2020         06/01/2021
#
#                 Ship Mode
# 0                 Express
# 1     Standard Processing
# 2     Standard Processing
# 3     Standard Processing
# 4     Standard Processing
# ...                   ...
# 5894  Standard Processing
# 5895  Standard Processing
# 5896  Standard Processing
# 5897  Standard Processing
# 5898  Standard Processing
#
# [5899 rows x 5 columns]

# %%
df_process.columns = df_process.columns.str.lower().str.replace(' ', '_')
df_process
# Out:
#       row_id        order_id  order_date on_truck_scan_date  \
# 0       3074  CA-2019-125206    3/1/2019         07/01/2019
# 1       4919  CA-2019-160304    2/1/2019         09/01/2019
# 2       4920  CA-2019-160304    2/1/2019         09/01/2019
# 3       8604  US-2019-116365    3/1/2019         09/01/2019
# 4       8605  US-2019-116365    3/1/2019         09/01/2019
# ...      ...             ...         ...                ...
# 5894     908  CA-2020-143259  30/12/2020         06/01/2021
# 5895     909  CA-2020-143259  30/12/2020         06/01/2021
# 5896    1297  CA-2020-115427  30/12/2020         06/01/2021
# 5897    1298  CA-2020-115427  30/12/2020         06/01/2021
# 5898    5092  CA-2020-156720  30/12/2020         06/01/2021
#
#                 ship_mode
# 0                 Express
# 1     Standard Processing
# 2     Standard Processing
# 3     Standard Processing
# 4     Standard Processing
# ...                   ...
# 5894  Standard Processing
# 5895  Standard Processing
# 5896  Standard Processing
# 5897  Standard Processing
# 5898  Standard Processing
#
# [5899 rows x 5 columns]

# %%
df_process.set_index('order_id', inplace=True)
df_process
# Out:
#                 row_id  order_date on_truck_scan_date            ship_mode
# order_id
# CA-2019-125206    3074    3/1/2019         07/01/2019              Express
# CA-2019-160304    4919    2/1/2019         09/01/2019  Standard Processing
# CA-2019-160304    4920    2/1/2019         09/01/2019  Standard Processing
# US-2019-116365    8604    3/1/2019         09/01/2019  Standard Processing
# US-2019-116365    8605    3/1/2019         09/01/2019  Standard Processing
# ...                ...         ...                ...                  ...
# CA-2020-143259     908  30/12/2020         06/01/2021  Standard Processing
# CA-2020-143259     909  30/12/2020         06/01/2021  Standard Processing
# CA-2020-115427    1297  30/12/2020         06/01/2021  Standard Processing
# CA-2020-115427    1298  30/12/2020         06/01/2021  Standard Processing
# CA-2020-156720    5092  30/12/2020         06/01/2021  Standard Processing
#
# [5899 rows x 4 columns]

# %%
merged_df = df_orders.merge(df_process, on='order_id', how='outer')
merged_df
# Out:
#                 Unnamed: 0  index order_date_x     ship_mode_x customer_id  \
# order_id
# CA-2019-121755           0     27   2019-01-16    Second Class    EH-13945
# CA-2019-121755           0     27   2019-01-16    Second Class    EH-13945
# CA-2019-121755        5558     26   2019-01-16    Second Class    EH-13945
# CA-2019-121755        5558     26   2019-01-16    Second Class    EH-13945
# CA-2019-118255           1     45   2019-03-11     First Class    ON-18715
# ...                    ...    ...          ...             ...         ...
# CA-2019-146913        9979   9760   2019-10-31  Standard Class    SF-20965
# US-2017-114377        9980   9787   2017-11-05     First Class    BG-11035
# CA-2020-107209        9984   9808   2020-07-27    Second Class    JW-15955
# US-2020-152842        9986   9830   2020-07-16  Standard Class    NF-18385
# CA-2019-122581        9988   9880   2019-08-21  Standard Class    JK-15370
#
#                    customer_name origin_channel country/region           city  \
# order_id
# CA-2019-121755     Eric Hoffmann          Email  United States    Los Angeles
# CA-2019-121755     Eric Hoffmann          Email  United States    Los Angeles
# CA-2019-121755     Eric Hoffmann          Email  United States    Los Angeles
# CA-2019-121755     Eric Hoffmann          Email  United States    Los Angeles
# CA-2019-118255     Odella Nelson          Sales  United States          Eagan
# ...                          ...            ...            ...            ...
# CA-2019-146913   Sylvia Foulston          Sales  United States  San Francisco
# US-2017-114377    Barry Gonzalez          Email  United States        Hampton
# CA-2020-107209    Joni Wasserman          Email  United States        Raleigh
# US-2020-152842  Natalie Fritzler          Email  United States      Charlotte
# CA-2019-122581        Jay Kimmel          Email  United States  New York City
#
#                          state  ...  discount   profit month day weekday  \
# order_id                        ...
# CA-2019-121755      California  ...       0.0  11.7741     1  16       2
# CA-2019-121755      California  ...       0.0  11.7741     1  16       2
# CA-2019-121755      California  ...       0.2   4.2224     1  16       2
# CA-2019-121755      California  ...       0.2   4.2224     1  16       2
# CA-2019-118255       Minnesota  ...       0.0  19.7714     3  11       0
# ...                        ...  ...       ...      ...   ...  ..     ...
# CA-2019-146913      California  ...       0.2  70.1960    10  31       3
# US-2017-114377        Virginia  ...       0.0  40.4730    11   5       6
# CA-2020-107209  North Carolina  ...       0.2  12.1780     7  27       0
# US-2020-152842  North Carolina  ...       0.2  15.1470     7  16       3
# CA-2019-122581        New York  ...       0.1  63.6860     8  21       2
#
#                 year  row_id  order_date_y  on_truck_scan_date  \
# order_id
# CA-2019-121755  2019    26.0     16/1/2019          23/01/2019
# CA-2019-121755  2019    27.0     16/1/2019          23/01/2019
# CA-2019-121755  2019    26.0     16/1/2019          23/01/2019
# CA-2019-121755  2019    27.0     16/1/2019          23/01/2019
# CA-2019-118255  2019    45.0     11/3/2019          13/03/2019
# ...              ...     ...           ...                 ...
# CA-2019-146913  2019  9760.0    31/10/2019          06/11/2019
# US-2017-114377  2017     NaN           NaN                 NaN
# CA-2020-107209  2020  9808.0     27/7/2020          05/08/2020
# US-2020-152842  2020  9830.0     16/7/2020          24/07/2020
# CA-2019-122581  2019  9880.0     21/8/2019          28/08/2019
#
#                         ship_mode_y
# order_id
# CA-2019-121755  Standard Processing
# CA-2019-121755  Standard Processing
# CA-2019-121755  Standard Processing
# CA-2019-121755  Standard Processing
# CA-2019-118255              Express
# ...                             ...
# CA-2019-146913  Standard Processing
# US-2017-114377                  NaN
# CA-2020-107209  Standard Processing
# US-2020-152842  Standard Processing
# CA-2019-122581  Standard Processing
#
# [21620 rows x 27 columns]

# %%
merged_df2 = pd.merge(df_campaign, df_intern, on='order_id', how='outer')
merged_df2
# Out:
#            order_id arrival_scan_date     customer_name ready_to_ship_date  \
# 0    CA-2019-109666        03/05/2019      Kunst Miller                NaN
# 1    CA-2019-138933        03/05/2019       Jack Lebron                NaN
# 2    CA-2019-130001        03/05/2019  Heather Kirkland                NaN
# 3    CA-2019-113061        06/05/2019         Ed Ludwig                NaN
# 4    CA-2019-162138        06/05/2019       Grace Kelly                NaN
# ..              ...               ...               ...                ...
# 596  US-2020-110576               NaN               NaN         04/12/2020
# 597  CA-2020-105333               NaN               NaN         04/12/2020
# 598  CA-2020-105333               NaN               NaN         04/12/2020
# 599  CA-2020-119305               NaN               NaN         04/12/2020
# 600  CA-2020-142090               NaN               NaN         07/12/2020
#
#     pickup_date
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ..          ...
# 596  07/12/2020
# 597  07/12/2020
# 598  07/12/2020
# 599  07/12/2020
# 600  09/12/2020
#
# [601 rows x 5 columns]

# %%
dff = pd.merge(merged_df, merged_df2, on='order_id', how='outer')
dff
# Out:
#              order_id  Unnamed: 0  index order_date_x     ship_mode_x  \
# 0      CA-2019-121755           0     27   2019-01-16    Second Class
# 1      CA-2019-121755           0     27   2019-01-16    Second Class
# 2      CA-2019-121755        5558     26   2019-01-16    Second Class
# 3      CA-2019-121755        5558     26   2019-01-16    Second Class
# 4      CA-2019-118255           1     45   2019-03-11     First Class
# ...               ...         ...    ...          ...             ...
# 23166  CA-2019-146913        9979   9760   2019-10-31  Standard Class
# 23167  US-2017-114377        9980   9787   2017-11-05     First Class
# 23168  CA-2020-107209        9984   9808   2020-07-27    Second Class
# 23169  US-2020-152842        9986   9830   2020-07-16  Standard Class
# 23170  CA-2019-122581        9988   9880   2019-08-21  Standard Class
#
#       customer_id   customer_name_x origin_channel country/region  \
# 0        EH-13945     Eric Hoffmann          Email  United States
# 1        EH-13945     Eric Hoffmann          Email  United States
# 2        EH-13945     Eric Hoffmann          Email  United States
# 3        EH-13945     Eric Hoffmann          Email  United States
# 4        ON-18715     Odella Nelson          Sales  United States
# ...           ...               ...            ...            ...
# 23166    SF-20965   Sylvia Foulston          Sales  United States
# 23167    BG-11035    Barry Gonzalez          Email  United States
# 23168    JW-15955    Joni Wasserman          Email  United States
# 23169    NF-18385  Natalie Fritzler          Email  United States
# 23170    JK-15370        Jay Kimmel          Email  United States
#
#                 city  ... weekday  year  row_id order_date_y  \
# 0        Los Angeles  ...       2  2019    26.0    16/1/2019
# 1        Los Angeles  ...       2  2019    27.0    16/1/2019
# 2        Los Angeles  ...       2  2019    26.0    16/1/2019
# 3        Los Angeles  ...       2  2019    27.0    16/1/2019
# 4              Eagan  ...       0  2019    45.0    11/3/2019
# ...              ...  ...     ...   ...     ...          ...
# 23166  San Francisco  ...       3  2019  9760.0   31/10/2019
# 23167        Hampton  ...       6  2017     NaN          NaN
# 23168        Raleigh  ...       0  2020  9808.0    27/7/2020
# 23169      Charlotte  ...       3  2020  9830.0    16/7/2020
# 23170  New York City  ...       2  2019  9880.0    21/8/2019
#
#       on_truck_scan_date          ship_mode_y  arrival_scan_date  \
# 0             23/01/2019  Standard Processing                NaN
# 1             23/01/2019  Standard Processing                NaN
# 2             23/01/2019  Standard Processing                NaN
# 3             23/01/2019  Standard Processing                NaN
# 4             13/03/2019              Express                NaN
# ...                  ...                  ...                ...
# 23166         06/11/2019  Standard Processing         11/11/2019
# 23167                NaN                  NaN                NaN
# 23168         05/08/2020  Standard Processing                NaN
# 23169         24/07/2020  Standard Processing                NaN
# 23170         28/08/2019  Standard Processing                NaN
#
#        customer_name_y  ready_to_ship_date  pickup_date
# 0                  NaN                 NaN          NaN
# 1                  NaN                 NaN          NaN
# 2                  NaN                 NaN          NaN
# 3                  NaN                 NaN          NaN
# 4                  NaN                 NaN          NaN
# ...                ...                 ...          ...
# 23166  Sylvia Foulston                 NaN          NaN
# 23167              NaN                 NaN          NaN
# 23168              NaN                 NaN          NaN
# 23169              NaN                 NaN          NaN
# 23170              NaN                 NaN          NaN
#
# [23171 rows x 32 columns]

# %%
dff.duplicated('order_id').sum()
# Out:
# 0

# %%
dff.drop_duplicates('order_id',inplace=True)

# %%
columns_to_drop = ['index']
dff.drop(columns=columns_to_drop, inplace=True)

# %%
dff.columns
# Out:
# Index(['order_id', 'order_date_x', 'ship_mode_x', 'customer_id',
#        'customer_name_x', 'origin_channel', 'country/region', 'city', 'state',
#        'postal_code', 'region', 'category', 'sub-category', 'product_id',
#        'sales', 'quantity', 'discount', 'profit', 'month', 'day', 'weekday',
#        'year', 'order_date_y', 'on_truck_scan_date', 'ship_mode_y',
#        'arrival_scan_date', 'customer_name_y', 'ready_to_ship_date',
#        'pickup_date'],
#       dtype='object')

# %%
#Create 3 KPI for delivery processes as columns:

#Order To Truck Time (order date - on truck scan date)
#Processing time (order date - ready to ship date)
#Waiting time (ready to ship date - on truck scan date)

# %%
dff['order_date_x'] = pd.to_datetime(dff['order_date_x'])
dff['ready_to_ship_date'] = pd.to_datetime(dff['ready_to_ship_date'], dayfirst=True)
dff['on_truck_scan_date'] = pd.to_datetime(dff['on_truck_scan_date'],dayfirst=True )

# %%
dff['Order_To_Truck_Time'] = (dff['on_truck_scan_date'] - dff['order_date_x']).dt.days
dff['Processing_Time'] = (dff['ready_to_ship_date'] - dff['order_date_x']).dt.days
dff['Waiting_Time'] = (dff['on_truck_scan_date'] - dff['ready_to_ship_date']).dt.days

dff
# Out:
#              order_id order_date_x     ship_mode_x customer_id  \
# 0      CA-2019-121755   2019-01-16    Second Class    EH-13945
# 4      CA-2019-118255   2019-03-11     First Class    ON-18715
# 8      CA-2019-169194   2019-06-20  Standard Class    LH-16900
# 12     CA-2019-111682   2019-06-17     First Class    TB-21055
# 61     CA-2018-135545   2018-11-24  Standard Class    KM-16720
# ...               ...          ...             ...         ...
# 23166  CA-2019-146913   2019-10-31  Standard Class    SF-20965
# 23167  US-2017-114377   2017-11-05     First Class    BG-11035
# 23168  CA-2020-107209   2020-07-27    Second Class    JW-15955
# 23169  US-2020-152842   2020-07-16  Standard Class    NF-18385
# 23170  CA-2019-122581   2019-08-21  Standard Class    JK-15370
#
#         customer_name_x origin_channel country/region           city  \
# 0         Eric Hoffmann          Email  United States    Los Angeles
# 4         Odella Nelson          Sales  United States          Eagan
# 8        Lena Hernandez          Email  United States          Dover
# 12      Ted Butterfield          Email  United States           Troy
# 61         Kunst Miller          Email  United States    Los Angeles
# ...                 ...            ...            ...            ...
# 23166   Sylvia Foulston          Sales  United States  San Francisco
# 23167    Barry Gonzalez          Email  United States        Hampton
# 23168    Joni Wasserman          Email  United States        Raleigh
# 23169  Natalie Fritzler          Email  United States      Charlotte
# 23170        Jay Kimmel          Email  United States  New York City
#
#                 state  postal_code  ... order_date_y on_truck_scan_date  \
# 0          California      90049.0  ...    16/1/2019         2019-01-23
# 4           Minnesota      55122.0  ...    11/3/2019         2019-03-13
# 8            Delaware      19901.0  ...    20/6/2019         2019-06-26
# 12           New York      12180.0  ...    17/6/2019         2019-06-19
# 61         California      90004.0  ...          NaN                NaT
# ...               ...          ...  ...          ...                ...
# 23166      California      94109.0  ...   31/10/2019         2019-11-06
# 23167        Virginia      23666.0  ...          NaN                NaT
# 23168  North Carolina      27604.0  ...    27/7/2020         2020-08-05
# 23169  North Carolina      28205.0  ...    16/7/2020         2020-07-24
# 23170        New York      10035.0  ...    21/8/2019         2019-08-28
#
#                ship_mode_y arrival_scan_date  customer_name_y  \
# 0      Standard Processing               NaN              NaN
# 4                  Express               NaN              NaN
# 8      Standard Processing               NaN              NaN
# 12                 Express               NaN              NaN
# 61                     NaN               NaN              NaN
# ...                    ...               ...              ...
# 23166  Standard Processing        11/11/2019  Sylvia Foulston
# 23167                  NaN               NaN              NaN
# 23168  Standard Processing               NaN              NaN
# 23169  Standard Processing               NaN              NaN
# 23170  Standard Processing               NaN              NaN
#
#        ready_to_ship_date  pickup_date  Order_To_Truck_Time  Processing_Time  \
# 0                     NaT          NaN                  7.0              NaN
# 4                     NaT          NaN                  2.0              NaN
# 8                     NaT          NaN                  6.0              NaN
# 12                    NaT          NaN                  2.0              NaN
# 61                    NaT          NaN                  NaN              NaN
# ...                   ...          ...                  ...              ...
# 23166                 NaT          NaN                  6.0              NaN
# 23167                 NaT          NaN                  NaN              NaN
# 23168                 NaT          NaN                  9.0              NaN
# 23169                 NaT          NaN                  8.0              NaN
# 23170                 NaT          NaN                  7.0              NaN
#
#        Waiting_Time
# 0               NaN
# 4               NaN
# 8               NaN
# 12              NaN
# 61              NaN
# ...             ...
# 23166           NaN
# 23167           NaN
# 23168           NaN
# 23169           NaN
# 23170           NaN
#
# [5009 rows x 32 columns]

# %%
plt.figure(figsize=(18, 6))
plt.subplot(1, 3, 3)
sns.histplot(data=dff, x='Order_To_Truck_Time', hue='ship_mode_x')
plt.title('Order to Truck Time Distribution by Ship Mode');

# %%
plt.figure(figsize=(18, 6))
plt.subplot(1, 3, 3)
sns.histplot(data=dff, x='Processing_Time', hue='ship_mode_x')
plt.title('Processing Days Distribution by Ship Mode')
# Out:
# Text(0.5, 1.0, 'Processing Days Distribution by Ship Mode')

# %%
plt.figure(figsize=(18, 6))
plt.subplot(1, 3, 3)
sns.histplot(data=dff, x='Waiting_Time', hue='ship_mode_x')
plt.title('Waiting Time Distribution by Ship Mode');

# %%
plt.figure(figsize=(15, 5))

# to plot distribution of "Order To Truck Time" split by ship mode
plt.subplot(1, 3, 1)
sns.histplot(data=dff, x='Order_To_Truck_Time', hue='ship_mode_y', kde=True)
plt.title('Distribution of Order To Truck Time by Ship Mode')

# to plot distribution of "Processing Time" split by ship mode
plt.subplot(1, 3, 2)
sns.histplot(data=dff, x='Processing_Time', hue='ship_mode_y', kde=True)
plt.title('Distribution of Processing Time by Ship Mode')

# to plot distribution of "Waiting Time" split by ship mode
plt.subplot(1, 3, 3)
sns.histplot(data=dff, x='Waiting_Time', hue='ship_mode_y', kde=True)
plt.title('Distribution of Waiting Time by Ship Mode');

# %%
df
# Out:
#       index        order_id order_date       ship_mode customer_id  \
# 0        27  CA-2019-121755 2019-01-16    Second Class    EH-13945
# 1        45  CA-2019-118255 2019-03-11     First Class    ON-18715
# 2        48  CA-2019-169194 2019-06-20  Standard Class    LH-16900
# 3        60  CA-2019-111682 2019-06-17     First Class    TB-21055
# 4        63  CA-2018-135545 2018-11-24  Standard Class    KM-16720
# ...     ...             ...        ...             ...         ...
# 9989   9894  US-2019-115441 2019-07-25    Second Class    SH-19975
# 9990   9908  US-2018-129007 2018-09-13     First Class    KD-16615
# 9991   9913  CA-2018-132388 2018-10-10     First Class    KN-16390
# 9992   9920  CA-2019-149272 2019-03-15  Standard Class    MY-18295
# 9993   9948  CA-2020-121559 2020-06-01    Second Class    HW-14935
#
#           customer_name orign_channel        country           city  \
# 0         Eric Hoffmann         Email  United States    Los Angeles
# 1         Odella Nelson         Sales  United States          Eagan
# 2        Lena Hernandez         Email  United States          Dover
# 3       Ted Butterfield         Email  United States           Troy
# 4          Kunst Miller         Email  United States    Los Angeles
# ...                 ...           ...            ...            ...
# 9989      Sally Hughsby         Sales  United States      Milwaukee
# 9990           Ken Dana         Sales  United States        Anaheim
# 9991  Katherine Nockton         Sales  United States  Santa Barbara
# 9992    Muhammed Yedwab         Sales  United States          Bryan
# 9993    Helen Wasserman         Sales  United States   Indianapolis
#
#            state  ...  sub_category       product_id     sales quantity  \
# 0     California  ...   Gluten Free  TEC-AC-10003027    90.570        3
# 1      Minnesota  ...   Gluten Free  TEC-AC-10000171    45.980        2
# 2       Delaware  ...   Gluten Free  TEC-AC-10002167    45.000        3
# 3       New York  ...   Gluten Free  TEC-AC-10002167    30.000        2
# 4     California  ...   Gluten Free  TEC-AC-10004633    13.980        2
# ...          ...  ...           ...              ...       ...      ...
# 9989   Wisconsin  ...     With Nuts  FUR-CH-10004626   403.560        4
# 9990  California  ...     With Nuts  FUR-CH-10000155   717.720        3
# 9991  California  ...     With Nuts  FUR-CH-10001714   362.136        3
# 9992       Texas  ...     With Nuts  FUR-CH-10000863   528.430        5
# 9993     Indiana  ...     With Nuts  FUR-CH-10003746  1925.880        6
#
#      discount    profit  month  weekday  day  year
# 0         0.0   11.7741      1        2   16  2019
# 1         0.0   19.7714      3        0   11  2019
# 2         0.0    4.9500      6        3   20  2019
# 3         0.0    3.3000      6        0   17  2019
# 4         0.0    6.1512     11        5   24  2018
# ...       ...       ...    ...      ...  ...   ...
# 9989      0.0   96.8544      7        3   25  2019
# 9990      0.2   71.7720      9        3   13  2018
# 9991      0.2  -54.3204     10        2   10  2018
# 9992      0.3 -143.4310      3        4   15  2019
# 9993      0.0  539.2464      6        0    1  2020
#
# [9994 rows x 23 columns]

# %%
columns_to_drop = ['index']
df.drop(columns=columns_to_drop, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[63], line 2
#       1 columns_to_drop = ['index']
# ----> 2 df.drop(columns=columns_to_drop, inplace=True)
#       3 df
#
# File ~/miniconda3/lib/python3.11/site-packages/pandas/core/frame.py:5344, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5196 def drop(
#    5197     self,
#    5198     labels: IndexLabel | None = None,
#    (...)
#    5205     errors: IgnoreRaise = "raise",
#    5206 ) -> DataFrame | None:
#    5207     """
#    5208     Drop specified labels from rows or columns.
#    5209
#    (...)
#    5342             weight  1.0     0.8
#    5343     """
# -> 5344     return super().drop(
#    5345         labels=labels,
#    5346         axis=axis,
#    5347         index=index,
#    5348         columns=columns,
#    5349         level=level,
#    5350         inplace=inplace,
#    5351         errors=errors,
#    5352     )
#
# File ~/miniconda3/lib/python3.11/site-packages/pandas/core/generic.py:4711, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4709 for axis, labels in axes.items():
#    4710     if labels is not None:
# -> 4711         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4713 if inplace:
#    4714     self._update_inplace(obj)
#
# File ~/miniconda3/lib/python3.11/site-packages/pandas/core/generic.py:4753, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4751         new_axis = axis.drop(labels, level=level, errors=errors)
#    4752     else:
# -> 4753         new_axis = axis.drop(labels, errors=errors)
#    4754     indexer = axis.get_indexer(new_axis)
#    4756 # Case for non-unique axis
#    4757 else:
#
# File ~/miniconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:6992, in Index.drop(self, labels, errors)
#    6990 if mask.any():
#    6991     if errors != "ignore":
# -> 6992         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    6993     indexer = indexer[~mask]
#    6994 return self.delete(indexer)
#
# KeyError: "['index'] not found in axis"

# %%
df
# Out:
#             order_id order_date       ship_mode customer_id  \
# 0     CA-2019-121755 2019-01-16    Second Class    EH-13945
# 1     CA-2019-118255 2019-03-11     First Class    ON-18715
# 2     CA-2019-169194 2019-06-20  Standard Class    LH-16900
# 3     CA-2019-111682 2019-06-17     First Class    TB-21055
# 4     CA-2018-135545 2018-11-24  Standard Class    KM-16720
# ...              ...        ...             ...         ...
# 9989  US-2019-115441 2019-07-25    Second Class    SH-19975
# 9990  US-2018-129007 2018-09-13     First Class    KD-16615
# 9991  CA-2018-132388 2018-10-10     First Class    KN-16390
# 9992  CA-2019-149272 2019-03-15  Standard Class    MY-18295
# 9993  CA-2020-121559 2020-06-01    Second Class    HW-14935
#
#           customer_name orign_channel        country           city  \
# 0         Eric Hoffmann         Email  United States    Los Angeles
# 1         Odella Nelson         Sales  United States          Eagan
# 2        Lena Hernandez         Email  United States          Dover
# 3       Ted Butterfield         Email  United States           Troy
# 4          Kunst Miller         Email  United States    Los Angeles
# ...                 ...           ...            ...            ...
# 9989      Sally Hughsby         Sales  United States      Milwaukee
# 9990           Ken Dana         Sales  United States        Anaheim
# 9991  Katherine Nockton         Sales  United States  Santa Barbara
# 9992    Muhammed Yedwab         Sales  United States          Bryan
# 9993    Helen Wasserman         Sales  United States   Indianapolis
#
#            state  postal_code  ... sub_category       product_id     sales  \
# 0     California      90049.0  ...  Gluten Free  TEC-AC-10003027    90.570
# 1      Minnesota      55122.0  ...  Gluten Free  TEC-AC-10000171    45.980
# 2       Delaware      19901.0  ...  Gluten Free  TEC-AC-10002167    45.000
# 3       New York      12180.0  ...  Gluten Free  TEC-AC-10002167    30.000
# 4     California      90004.0  ...  Gluten Free  TEC-AC-10004633    13.980
# ...          ...          ...  ...          ...              ...       ...
# 9989   Wisconsin      53209.0  ...    With Nuts  FUR-CH-10004626   403.560
# 9990  California      92804.0  ...    With Nuts  FUR-CH-10000155   717.720
# 9991  California      93101.0  ...    With Nuts  FUR-CH-10001714   362.136
# 9992       Texas      77803.0  ...    With Nuts  FUR-CH-10000863   528.430
# 9993     Indiana      46203.0  ...    With Nuts  FUR-CH-10003746  1925.880
#
#      quantity  discount    profit  month  weekday  day  year
# 0           3       0.0   11.7741      1        2   16  2019
# 1           2       0.0   19.7714      3        0   11  2019
# 2           3       0.0    4.9500      6        3   20  2019
# 3           2       0.0    3.3000      6        0   17  2019
# 4           2       0.0    6.1512     11        5   24  2018
# ...       ...       ...       ...    ...      ...  ...   ...
# 9989        4       0.0   96.8544      7        3   25  2019
# 9990        3       0.2   71.7720      9        3   13  2018
# 9991        3       0.2  -54.3204     10        2   10  2018
# 9992        5       0.3 -143.4310      3        4   15  2019
# 9993        6       0.0  539.2464      6        0    1  2020
#
# [9994 rows x 22 columns]

# %%
df['order_date'] = pd.to_datetime(df['order_date'])

# %%
#1.Filter muesli order data for one month


muesli_orders_nov_2020 = df[(df['order_date'].dt.month == 11) & (df['order_date'].dt.year == 2020)]
muesli_orders_nov_2020
# Out:
#             order_id order_date       ship_mode customer_id  \
# 8     CA-2020-119004 2020-11-23  Standard Class    JM-15250
# 43    CA-2020-135307 2020-11-26     First Class    LS-17245
# 79    CA-2020-102519 2020-11-27     First Class    BM-11650
# 82    US-2020-111745 2020-11-05     First Class    RA-19885
# 102   US-2020-155425 2020-11-10     First Class    AB-10600
# ...              ...        ...             ...         ...
# 9929  CA-2020-150266 2020-11-25  Standard Class    RO-19780
# 9948  US-2020-165456 2020-11-30     First Class    TB-21625
# 9955  CA-2020-113460 2020-11-07    Second Class    KN-16390
# 9963  US-2020-109610 2020-11-25    Second Class    BS-11590
# 9964  CA-2020-102925 2020-11-05    Second Class    CD-12280
#
#           customer_name orign_channel        country           city  \
# 8          Janet Martin         Email  United States      Charlotte
# 43           Lynn Smith         Email  United States      Gladstone
# 79           Brian Moss         Sales  United States      Milwaukee
# 82         Ruben Ausman         Sales  United States     Farmington
# 102           Ann Blume         Sales  United States         Tucson
# ...                 ...           ...            ...            ...
# 9929       Rose O'Brian         Email  United States        Houston
# 9948        Trudy Brown         Email  United States   Philadelphia
# 9955  Katherine Nockton         Sales  United States        Clinton
# 9963      Brendan Sweed         Sales  United States     Louisville
# 9964   Christina DeMoss         Email  United States  New York City
#
#                state  postal_code  ... sub_category       product_id  \
# 8     North Carolina      28205.0  ...  Gluten Free  TEC-AC-10003499
# 43          Missouri      64118.0  ...  Gluten Free  TEC-AC-10002399
# 79         Wisconsin      53209.0  ...  Gluten Free  TEC-AC-10001772
# 82        New Mexico      87401.0  ...  Gluten Free  TEC-AC-10003911
# 102          Arizona      85705.0  ...  Gluten Free  TEC-AC-10001314
# ...              ...          ...  ...          ...              ...
# 9929           Texas      77070.0  ...    With Nuts  FUR-CH-10002126
# 9948    Pennsylvania      19134.0  ...    With Nuts  FUR-CH-10003981
# 9955        Maryland      20735.0  ...    With Nuts  FUR-CH-10000422
# 9963        Kentucky      40214.0  ...    With Nuts  FUR-CH-10001854
# 9964        New York      10024.0  ...    With Nuts  FUR-CH-10004875
#
#          sales quantity  discount    profit  month  weekday  day  year
# 8       74.112        8       0.2   17.6016     11        0   23  2020
# 43      38.040        2       0.0   12.1728     11        3   26  2020
# 79     143.730        9       0.0   56.0547     11        4   27  2020
# 82     159.990        1       0.0   54.3966     11        3    5  2020
# 102    239.952        6       0.2  -35.9928     11        1   10  2020
# ...        ...      ...       ...       ...    ...      ...  ...   ...
# 9929   853.930        5       0.3  -24.3980     11        2   25  2020
# 9948  1079.316        6       0.3  -15.4188     11        0   30  2020
# 9955   272.970        3       0.0   43.6752     11        5    7  2020
# 9963   701.960        2       0.0  168.4704     11        2   25  2020
# 9964   128.124        2       0.1   24.2012     11        3    5  2020
#
# [459 rows x 22 columns]

# %%
#2.Using sns.displot() plot the distribution of the quantity during that month


sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.displot(muesli_orders_nov_2020['quantity'], kde=True, color='r')
plt.title('Distribution of Quantity in November 2020')
plt.xlabel('Quantity')
plt.ylabel('Frequency');

# %%
#3.Filter muesli order data for the year 2017 and Los Angeles city

df_2017_los_angeles = df[(df['order_date'].dt.year == 2017) & (df['city'] == 'Los Angeles')]
df_2017_los_angeles
# Out:
#             order_id order_date       ship_mode customer_id     customer_name  \
# 13    CA-2017-123260 2017-08-26  Standard Class    FM-14290      Frank Merwin
# 116   US-2017-157385 2017-11-23     First Class    SC-20095      Sanjit Chand
# 161   CA-2017-106439 2017-10-31  Standard Class    GG-14650      Greg Guthrie
# 238   CA-2017-136399 2017-12-16     First Class    CC-12100   Chad Cunningham
# 330   CA-2017-138436 2017-03-26  Standard Class    JD-15895  Jonathan Doherty
# ...              ...        ...             ...         ...               ...
# 9564  CA-2017-136399 2017-12-16     First Class    CC-12100   Chad Cunningham
# 9699  CA-2017-113768 2017-05-13  Standard Class    AH-10030     Aaron Hawkins
# 9721  CA-2017-105270 2017-11-11  Standard Class    AP-10915    Arthur Prichep
# 9853  US-2017-144078 2017-11-25  Standard Class    RB-19435   Richard Bierner
# 9866  CA-2017-125150 2017-05-16  Standard Class    PW-19030    Pauline Webber
#
#      orign_channel        country         city       state  postal_code  ...  \
# 13        Facebook  United States  Los Angeles  California      90032.0  ...
# 116          Email  United States  Los Angeles  California      90004.0  ...
# 161          Sales  United States  Los Angeles  California      90049.0  ...
# 238       Facebook  United States  Los Angeles  California      90049.0  ...
# 330          Sales  United States  Los Angeles  California      90036.0  ...
# ...            ...            ...          ...         ...          ...  ...
# 9564      Facebook  United States  Los Angeles  California      90049.0  ...
# 9699         Sales  United States  Los Angeles  California      90004.0  ...
# 9721         Email  United States  Los Angeles  California      90008.0  ...
# 9853         Email  United States  Los Angeles  California      90004.0  ...
# 9866         Sales  United States  Los Angeles  California      90036.0  ...
#
#      sub_category       product_id    sales quantity  discount   profit  \
# 13    Gluten Free  TEC-AC-10002323  176.800        8       0.0  22.9840
# 116   Gluten Free  TEC-AC-10003280   29.990        1       0.0   6.2979
# 161   Gluten Free  TEC-AC-10004568  251.910        9       0.0  47.8629
# 238   Gluten Free  TEC-AC-10001142  395.000        5       0.0  39.5000
# 330   Gluten Free  TEC-AC-10002323   66.300        3       0.0   8.6190
# ...           ...              ...      ...      ...       ...      ...
# 9564    With Nuts  FUR-CH-10002602  241.568        2       0.2  18.1176
# 9699    With Nuts  FUR-CH-10002439  279.456        6       0.2  20.9592
# 9721    With Nuts  FUR-CH-10000988  112.648        1       0.2  11.2648
# 9853    With Nuts  FUR-CH-10002335  725.344        4       0.2  54.4008
# 9866    With Nuts  FUR-CH-10002439  232.880        5       0.2  17.4660
#
#       month  weekday  day  year
# 13        8        5   26  2017
# 116      11        3   23  2017
# 161      10        1   31  2017
# 238      12        5   16  2017
# 330       3        6   26  2017
# ...     ...      ...  ...   ...
# 9564     12        5   16  2017
# 9699      5        5   13  2017
# 9721     11        5   11  2017
# 9853     11        5   25  2017
# 9866      5        1   16  2017
#
# [156 rows x 22 columns]

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(18, 6))
sns.displot(df_2017_los_angeles['discount'], kde=True, color='magenta')
plt.title('Distribution of Discount in Los Angeles in 2017')
plt.xlabel('Discount')
plt.ylabel('Frequency');

# %%
#plot profit Los Angeles 2017


sns.set(style="whitegrid")
plt.figure(figsize=(18, 6))
sns.displot(df_2017_los_angeles['profit'], kde=True, color='green')
plt.title('Distribution of Profit in Los Angeles in 2017')
plt.xlabel('Profit')
plt.ylabel('Frequency');

# %%
#plot discounts Los Angeles 2017

sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.kdeplot(data=df_2017_los_angeles['discount'],color='c', fill=True)

plt.title('Distribution of Discounts in Los Angeles in 2017')
plt.xlabel('discount')
plt.ylabel('frequency');

# %%
sns.displot(data=df_2017_los_angeles, x="quantity", hue="ship_mode", multiple="stack");

# %%
df
# Out:
#             order_id order_date       ship_mode customer_id  \
# 0     CA-2019-121755 2019-01-16    Second Class    EH-13945
# 1     CA-2019-118255 2019-03-11     First Class    ON-18715
# 2     CA-2019-169194 2019-06-20  Standard Class    LH-16900
# 3     CA-2019-111682 2019-06-17     First Class    TB-21055
# 4     CA-2018-135545 2018-11-24  Standard Class    KM-16720
# ...              ...        ...             ...         ...
# 9989  US-2019-115441 2019-07-25    Second Class    SH-19975
# 9990  US-2018-129007 2018-09-13     First Class    KD-16615
# 9991  CA-2018-132388 2018-10-10     First Class    KN-16390
# 9992  CA-2019-149272 2019-03-15  Standard Class    MY-18295
# 9993  CA-2020-121559 2020-06-01    Second Class    HW-14935
#
#           customer_name orign_channel        country           city  \
# 0         Eric Hoffmann         Email  United States    Los Angeles
# 1         Odella Nelson         Sales  United States          Eagan
# 2        Lena Hernandez         Email  United States          Dover
# 3       Ted Butterfield         Email  United States           Troy
# 4          Kunst Miller         Email  United States    Los Angeles
# ...                 ...           ...            ...            ...
# 9989      Sally Hughsby         Sales  United States      Milwaukee
# 9990           Ken Dana         Sales  United States        Anaheim
# 9991  Katherine Nockton         Sales  United States  Santa Barbara
# 9992    Muhammed Yedwab         Sales  United States          Bryan
# 9993    Helen Wasserman         Sales  United States   Indianapolis
#
#            state  postal_code  ... sub_category       product_id     sales  \
# 0     California      90049.0  ...  Gluten Free  TEC-AC-10003027    90.570
# 1      Minnesota      55122.0  ...  Gluten Free  TEC-AC-10000171    45.980
# 2       Delaware      19901.0  ...  Gluten Free  TEC-AC-10002167    45.000
# 3       New York      12180.0  ...  Gluten Free  TEC-AC-10002167    30.000
# 4     California      90004.0  ...  Gluten Free  TEC-AC-10004633    13.980
# ...          ...          ...  ...          ...              ...       ...
# 9989   Wisconsin      53209.0  ...    With Nuts  FUR-CH-10004626   403.560
# 9990  California      92804.0  ...    With Nuts  FUR-CH-10000155   717.720
# 9991  California      93101.0  ...    With Nuts  FUR-CH-10001714   362.136
# 9992       Texas      77803.0  ...    With Nuts  FUR-CH-10000863   528.430
# 9993     Indiana      46203.0  ...    With Nuts  FUR-CH-10003746  1925.880
#
#      quantity  discount    profit  month  weekday  day  year
# 0           3       0.0   11.7741      1        2   16  2019
# 1           2       0.0   19.7714      3        0   11  2019
# 2           3       0.0    4.9500      6        3   20  2019
# 3           2       0.0    3.3000      6        0   17  2019
# 4           2       0.0    6.1512     11        5   24  2018
# ...       ...       ...       ...    ...      ...  ...   ...
# 9989        4       0.0   96.8544      7        3   25  2019
# 9990        3       0.2   71.7720      9        3   13  2018
# 9991        3       0.2  -54.3204     10        2   10  2018
# 9992        5       0.3 -143.4310      3        4   15  2019
# 9993        6       0.0  539.2464      6        0    1  2020
#
# [9994 rows x 22 columns]

# %%
import numpy as np

# %%
#1. Initialize an empty list called sample_means
sample_means = []

#2. Create a for loop that will loop 10,000 times
for i in range(10000):
    #3. In each iteration, use the pandas method .sample() to sample 100 profits with replacement
    sample = df['profit'].sample(100, replace=True)
    
    #4.Take the mean of these 100 samples and append it to the sample_means list
    sample_mean = np.mean(sample)
    sample_means.append(sample_mean)

# 5.Using sns.displot, plot the distribution of the sample_means list
sns.set(style="whitegrid")
g = sns.displot(sample_means, kde=True, height=8, aspect=1.5, color='green')
g.fig.suptitle('Distribution of Sample Means', fontsize=16, fontweight='bold')
g.set_axis_labels('Sample Mean', 'Frequency', fontsize=12, fontweight='bold')
g.fig.subplots_adjust(top=0.9)
g.ax.margins(x=0)

# %%
# 6.Convert sample_means list to pandas Series
sample_means_series = pd.Series(sample_means)

# %%
#7.Using pandas .quantile(), calculate the upper (0.975) and lower (0.025) limits of the confidence interval
alpha= 0.95
lower_quantile = (1-alpha)/2
upper_quantile= alpha+((1-alpha)/2)

print(alpha,lower_quantile,upper_quantile)
# Out:
# 0.95 0.025000000000000022 0.975

# %%
lower_limit= sample_means_series.quantile(lower_quantile)
upper_limit = sample_means_series.quantile(upper_quantile)
print(alpha,lower_limit,upper_limit)
# Out:
# 0.95 -15.518575699999984 86.470772275

# %%
sample_means=sample_means_series.mean()
sample_std= sample_means_series.std()
print(sample_means,sample_std)
# Out:
# 28.6372063549 23.728223027508967

# %%
#Calculate using the z-value formula
z=1.96
n=len('profit')
lower_limit_eq=sample_means-((z*sample)/np.sqrt(n))
upper_limit_eq=sample_means-((z*sample)/np.sqrt(n))
print(lower_limit_eq,upper_limit_eq)
# Out:
# 7617     27.201707
# 9427    -43.848290
# 5270     20.644982
# 2102     27.042794
# 3875   -107.800249
#            ...
# 8123     23.262007
# 9868     23.521261
# 6943    -24.580917
# 8943     26.158610
# 1220     28.183672
# Name: profit, Length: 100, dtype: float64 7617     27.201707
# 9427    -43.848290
# 5270     20.644982
# 2102     27.042794
# 3875   -107.800249
#            ...
# 8123     23.262007
# 9868     23.521261
# 6943    -24.580917
# 8943     26.158610
# 1220     28.183672
# Name: profit, Length: 100, dtype: float64

# %%
import scipy.stats as sps
import statsmodels.api as sm
import seaborn as sns
from statsmodels.stats.proportion import proportions_ztest

# %%
df = pd.read_csv('/Users/lamiaebenouahi/Desktop/Spiced Bootcamp/GitHub/lemongrass-regression-student-code/week_05_explanatory_da/data/muesli_orders.csv',parse_dates=['Order Date'], header=1)
# Out:
# /var/folders/kn/69gx8nmx0z3b3y98m_v_21tr0000gn/T/ipykernel_26581/3156498167.py:1: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df = pd.read_csv('/Users/lamiaebenouahi/Desktop/Spiced Bootcamp/GitHub/lemongrass-regression-student-code/week_05_explanatory_da/data/muesli_orders.csv',parse_dates=['Order Date'], header=1)

# %%
df.columns = df.columns.str.lower().str.replace(' ', '_')

# %%
df['order_date']= pd.to_datetime(df['order_date'],dayfirst=True)
df
# Out:
#       index        order_id order_date       ship_mode customer_id  \
# 0        27  CA-2019-121755 2019-01-16    Second Class    EH-13945
# 1        45  CA-2019-118255 2019-03-11     First Class    ON-18715
# 2        48  CA-2019-169194 2019-06-20  Standard Class    LH-16900
# 3        60  CA-2019-111682 2019-06-17     First Class    TB-21055
# 4        63  CA-2018-135545 2018-11-24  Standard Class    KM-16720
# ...     ...             ...        ...             ...         ...
# 9989   9894  US-2019-115441 2019-07-25    Second Class    SH-19975
# 9990   9908  US-2018-129007 2018-09-13     First Class    KD-16615
# 9991   9913  CA-2018-132388 2018-10-10     First Class    KN-16390
# 9992   9920  CA-2019-149272 2019-03-15  Standard Class    MY-18295
# 9993   9948  CA-2020-121559 2020-06-01    Second Class    HW-14935
#
#           customer_name origin_channel country/region           city  \
# 0         Eric Hoffmann          Email  United States    Los Angeles
# 1         Odella Nelson          Sales  United States          Eagan
# 2        Lena Hernandez          Email  United States          Dover
# 3       Ted Butterfield          Email  United States           Troy
# 4          Kunst Miller          Email  United States    Los Angeles
# ...                 ...            ...            ...            ...
# 9989      Sally Hughsby          Sales  United States      Milwaukee
# 9990           Ken Dana          Sales  United States        Anaheim
# 9991  Katherine Nockton          Sales  United States  Santa Barbara
# 9992    Muhammed Yedwab          Sales  United States          Bryan
# 9993    Helen Wasserman          Sales  United States   Indianapolis
#
#            state  postal_code   region                 category sub-category  \
# 0     California      90049.0     West  Special Projects Muesil  Gluten Free
# 1      Minnesota      55122.0  Central  Special Projects Muesil  Gluten Free
# 2       Delaware      19901.0     East  Special Projects Muesil  Gluten Free
# 3       New York      12180.0     East  Special Projects Muesil  Gluten Free
# 4     California      90004.0     West  Special Projects Muesil  Gluten Free
# ...          ...          ...      ...                      ...          ...
# 9989   Wisconsin      53209.0  Central           Toasted Muesli    With Nuts
# 9990  California      92804.0     West           Toasted Muesli    With Nuts
# 9991  California      93101.0     West           Toasted Muesli    With Nuts
# 9992       Texas      77803.0  Central           Toasted Muesli    With Nuts
# 9993     Indiana      46203.0  Central           Toasted Muesli    With Nuts
#
#            product_id     sales  quantity  discount    profit
# 0     TEC-AC-10003027    90.570         3       0.0   11.7741
# 1     TEC-AC-10000171    45.980         2       0.0   19.7714
# 2     TEC-AC-10002167    45.000         3       0.0    4.9500
# 3     TEC-AC-10002167    30.000         2       0.0    3.3000
# 4     TEC-AC-10004633    13.980         2       0.0    6.1512
# ...               ...       ...       ...       ...       ...
# 9989  FUR-CH-10004626   403.560         4       0.0   96.8544
# 9990  FUR-CH-10000155   717.720         3       0.2   71.7720
# 9991  FUR-CH-10001714   362.136         3       0.2  -54.3204
# 9992  FUR-CH-10000863   528.430         5       0.3 -143.4310
# 9993  FUR-CH-10003746  1925.880         6       0.0  539.2464
#
# [9994 rows x 19 columns]

# %%
channel_email = df[df['origin_channel'] == 'Email']
channel_email
# Out:
#       index        order_id order_date       ship_mode customer_id  \
# 0        27  CA-2019-121755 2019-01-16    Second Class    EH-13945
# 2        48  CA-2019-169194 2019-06-20  Standard Class    LH-16900
# 3        60  CA-2019-111682 2019-06-17     First Class    TB-21055
# 4        63  CA-2018-135545 2018-11-24  Standard Class    KM-16720
# 5        87  CA-2020-155558 2020-10-26  Standard Class    PG-18895
# ...     ...             ...        ...             ...         ...
# 9984   9808  CA-2020-107209 2020-07-27    Second Class    JW-15955
# 9985   9827  US-2017-164406 2017-08-15  Standard Class    BD-11605
# 9986   9830  US-2020-152842 2020-07-16  Standard Class    NF-18385
# 9987   9843  US-2019-125402 2019-09-25  Standard Class    DL-12865
# 9988   9880  CA-2019-122581 2019-08-21  Standard Class    JK-15370
#
#          customer_name origin_channel country/region           city  \
# 0        Eric Hoffmann          Email  United States    Los Angeles
# 2       Lena Hernandez          Email  United States          Dover
# 3      Ted Butterfield          Email  United States           Troy
# 4         Kunst Miller          Email  United States    Los Angeles
# 5        Paul Gonzalez          Email  United States      Rochester
# ...                ...            ...            ...            ...
# 9984    Joni Wasserman          Email  United States        Raleigh
# 9985      Brian Dahlen          Email  United States  San Francisco
# 9986  Natalie Fritzler          Email  United States      Charlotte
# 9987        Dan Lawera          Email  United States     Long Beach
# 9988        Jay Kimmel          Email  United States  New York City
#
#                state  postal_code   region                 category  \
# 0         California      90049.0     West  Special Projects Muesil
# 2           Delaware      19901.0     East  Special Projects Muesil
# 3           New York      12180.0     East  Special Projects Muesil
# 4         California      90004.0     West  Special Projects Muesil
# 5          Minnesota      55901.0  Central  Special Projects Muesil
# ...              ...          ...      ...                      ...
# 9984  North Carolina      27604.0    South           Toasted Muesli
# 9985      California      94122.0     West           Toasted Muesli
# 9986  North Carolina      28205.0    South           Toasted Muesli
# 9987      California      90805.0     West           Toasted Muesli
# 9988        New York      10035.0     East           Toasted Muesli
#
#      sub-category       product_id    sales  quantity  discount   profit
# 0     Gluten Free  TEC-AC-10003027   90.570         3       0.0  11.7741
# 2     Gluten Free  TEC-AC-10002167   45.000         3       0.0   4.9500
# 3     Gluten Free  TEC-AC-10002167   30.000         2       0.0   3.3000
# 4     Gluten Free  TEC-AC-10004633   13.980         2       0.0   6.1512
# 5     Gluten Free  TEC-AC-10001998   19.990         1       0.0   6.7966
# ...           ...              ...      ...       ...       ...      ...
# 9984    With Nuts  FUR-CH-10001146  194.848         4       0.2  12.1780
# 9985    With Nuts  FUR-CH-10003833  195.136         4       0.2 -12.1960
# 9986    With Nuts  FUR-CH-10004218  242.352         3       0.2  15.1470
# 9987    With Nuts  FUR-CH-10000665  483.136         4       0.2  60.3920
# 9988    With Nuts  FUR-CH-10002961  573.174         7       0.1  63.6860
#
# [5191 rows x 19 columns]

# %%
channel_email['email']=channel_email['sales']
channel_email=channel_email[['email']]
channel_email
# Out:
# /var/folders/kn/69gx8nmx0z3b3y98m_v_21tr0000gn/T/ipykernel_26581/691846823.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   channel_email['email']=channel_email['sales']
#         email
# 0      90.570
# 2      45.000
# 3      30.000
# 4      13.980
# 5      19.990
# ...       ...
# 9984  194.848
# 9985  195.136
# 9986  242.352
# 9987  483.136
# 9988  573.174
#
# [5191 rows x 1 columns]

# %%
channel_fb = df[df['origin_channel'] == 'Facebook']
channel_fb
# Out:
#       index        order_id order_date       ship_mode customer_id  \
# 6       101  CA-2019-158568 2019-08-29  Standard Class    RB-19465
# 9       110  CA-2018-129476 2018-10-15  Standard Class    PA-19060
# 12      185  CA-2017-158274 2017-11-19    Second Class    RM-19675
# 13      187  CA-2017-123260 2017-08-26  Standard Class    FM-14290
# 16      236  US-2020-100930 2020-04-07  Standard Class    CS-12400
# ...     ...             ...        ...             ...         ...
# 9935   9057  CA-2018-160227 2018-11-02     First Class    ED-13885
# 9943   9262  CA-2020-111388 2020-09-02     First Class    SU-20665
# 9952   9348  CA-2020-109085 2020-02-17     First Class    CK-12325
# 9966   9541  CA-2018-135727 2018-05-11    Second Class    PS-18970
# 9970   9582  CA-2020-152975 2020-09-14     First Class    RB-19705
#
#            customer_name origin_channel country/region           city  \
# 6           Rick Bensley       Facebook  United States        Chicago
# 9         Pete Armstrong       Facebook  United States    Orland Park
# 12         Robert Marley       Facebook  United States         Monroe
# 13          Frank Merwin       Facebook  United States    Los Angeles
# 16    Christopher Schild       Facebook  United States          Tampa
# ...                  ...            ...            ...            ...
# 9935        Emily Ducich       Facebook  United States  New York City
# 9943  Stephanie Ulpright       Facebook  United States        Seattle
# 9952  Christine Kargatis       Facebook  United States           Troy
# 9966      Paul Stevenson       Facebook  United States        Phoenix
# 9970        Roger Barcio       Facebook  United States  New York City
#
#            state  postal_code   region                 category sub-category  \
# 6       Illinois      60610.0  Central  Special Projects Muesil  Gluten Free
# 9       Illinois      60462.0  Central  Special Projects Muesil  Gluten Free
# 12     Louisiana      71203.0    South  Special Projects Muesil  Gluten Free
# 13    California      90032.0     West  Special Projects Muesil  Gluten Free
# 16       Florida      33614.0    South  Special Projects Muesil  Gluten Free
# ...          ...          ...      ...                      ...          ...
# 9935    New York      10011.0     East           Toasted Muesli    With Nuts
# 9943  Washington      98103.0     West           Toasted Muesli    With Nuts
# 9952        Ohio      45373.0     East           Toasted Muesli    With Nuts
# 9966     Arizona      85023.0     West           Toasted Muesli    With Nuts
# 9970    New York      10035.0     East           Toasted Muesli    With Nuts
#
#            product_id     sales  quantity  discount    profit
# 6     TEC-AC-10001767    95.976         3       0.2  -10.7973
# 9     TEC-AC-10000844   339.960         5       0.2   67.9920
# 12    TEC-AC-10002345    29.000         2       0.0    7.2500
# 13    TEC-AC-10002323   176.800         8       0.0   22.9840
# 16    TEC-AC-10003832   617.976         3       0.2   -7.7247
# ...               ...       ...       ...       ...       ...
# 9935  FUR-CH-10002073  2621.322        11       0.1  553.3902
# 9943  FUR-CH-10003061   215.976         3       0.2   -2.6997
# 9952  FUR-CH-10003981   899.430         5       0.3  -12.8490
# 9966  FUR-CH-10004540   191.968         7       0.2   16.7972
# 9970  FUR-CH-10003298   589.410         5       0.1   -6.5490
#
# [1783 rows x 19 columns]

# %%
channel_fb['Facebook']=channel_fb['sales']
channel_fb=channel_fb[['Facebook']]
channel_fb
# Out:
# /var/folders/kn/69gx8nmx0z3b3y98m_v_21tr0000gn/T/ipykernel_26581/2241563285.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   channel_fb['Facebook']=channel_fb['sales']
#       Facebook
# 6       95.976
# 9      339.960
# 12      29.000
# 13     176.800
# 16     617.976
# ...        ...
# 9935  2621.322
# 9943   215.976
# 9952   899.430
# 9966   191.968
# 9970   589.410
#
# [1783 rows x 1 columns]

# %%
test_statistic, pvalue = sps.ttest_ind(channel_fb, channel_email)
print(f'the average sales for channel: {channel_fb.mean()}')
print(f'the average sales for channel: {channel_email.mean()}')
print(test_statistic, pvalue)
# Out:
# the average sales for channel: Facebook    240.972041
# dtype: float64
# the average sales for channel: email    223.733644
# dtype: float64
# [0.99158883] [0.32143255]

# %%
colors = ['Blue', 'Red']

plt.bar(['Facebook', 'Email'], [channel_fb.mean().values[0], channel_email.mean().values[0]], color=colors)
plt.title('Average Sales for Each Channel')
plt.ylabel('Average Sales')
plt.show()

# %%
ship_mode_num = {'Second Class': 2, 'Standard Class': 3, 'First Class': 1}

df['ship_mode_numeric'] = df['ship_mode'].map(ship_mode_num)

print(df[['ship_mode', 'ship_mode_numeric']])
# Out:
#            ship_mode  ship_mode_numeric
# 0       Second Class                  2
# 1        First Class                  1
# 2     Standard Class                  3
# 3        First Class                  1
# 4     Standard Class                  3
# ...              ...                ...
# 9989    Second Class                  2
# 9990     First Class                  1
# 9991     First Class                  1
# 9992  Standard Class                  3
# 9993    Second Class                  2
#
# [9994 rows x 2 columns]

# %%
from scipy.stats import zscore

# %%
selected_ship_modes = ['First Class', 'Standard Class']
selected_data = df[df['ship_mode'].isin(selected_ship_modes)]

group_first = selected_data[selected_data['ship_mode'] == selected_ship_modes[0]]['quantity']
group_standard = selected_data[selected_data['ship_mode'] == selected_ship_modes[1]]['quantity']

test_statistic, pvalue = sps.ttest_ind(group_first, group_standard)

print(f'Test Statistic: {test_statistic}')
print(f'P-value: {pvalue}')
# Out:
# Test Statistic: -2.523735654752176
# P-value: 0.011630609877289023

# %% [markdown]
# ## Interpretation:
#
# The t-test results suggest that there is a statistically significant difference in the average quantity between 'First Class' and 'Standard Class' shipping modes. The negative test statistic indicates that, on average, the quantity for 'First Class' is lower than that for 'Standard Class'. The small p-value suggests that this difference is unlikely to be due to random chance so we succeed to reject H0.

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='ship_mode', y='quantity', data=selected_data)
plt.title('Distribution of Quantities for Different Ship Modes')
plt.xlabel('Ship Mode')
plt.ylabel('Quantity')
# Out:
# Text(0, 0.5, 'Quantity')

# %%
plt.figure(figsize=(10, 6))
sns.kdeplot(data=selected_data, x='quantity', hue='ship_mode', fill=True)
plt.title('Quantities for Different Ship Modes')
plt.xlabel('Quantity')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data=selected_data, x='quantity', hue='ship_mode', bins=20, edgecolor='green')
plt.title('Histogram of Quantities for Different Ship Modes')
plt.xlabel('Quantity')
plt.ylabel('Count')

plt.show()

# %%
selected_ship_modes = ['First Class', 'Standard Class']
selected_data = df[df['ship_mode'].isin(selected_ship_modes)]

group_0 = selected_data[selected_data['ship_mode'] == selected_ship_modes[0]]['discount']
group_1 = selected_data[selected_data['ship_mode'] == selected_ship_modes[1]]['discount']

test_statistic, pvalue = sps.ttest_ind(group_0, group_1)

print(f'Test Statistic: {test_statistic}')
print(f'P-value: {pvalue}')
# Out:
# Test Statistic: 0.261816310866955
# P-value: 0.7934697644173507

# %% [markdown]
# ## Interpretation:
#
# The t-test results indicate that there is no statistically significant difference in discounts between 'First Class' and 'Standard Class'. The positive test statistic suggests a small average difference, but the high p-value suggests that this difference is likely due to random chance rather than a meaningful distinction between the two shipping modes so we fail to reject H0.

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data=selected_data, x='discount', hue='ship_mode', multiple='stack', bins=20, edgecolor='black')
plt.title('Histogram of Discounts for Different Ship Modes')
plt.xlabel('Discount')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
selected_ship_modes = ['First Class', 'Standard Class']
group_0 = df[df['ship_mode'] == selected_ship_modes[0]]['profit']
group_1 = df[df['ship_mode'] == selected_ship_modes[1]]['profit']

test_statistic, pvalue = sps.ttest_ind(group_0, group_1, equal_var=False)

print(f'Test Statistic: {test_statistic}')
print(f'P-value: {pvalue}')
# Out:
# Test Statistic: 0.5772157892970565
# P-value: 0.5638294903500132

# %% [markdown]
# ## Interpretation
#
# The t-test results suggest that there is no statistically significant difference in the mean profit between 'First Class' and 'Standard Class' ship modes. The positive test statistic indicates a small average difference, but the high p-value suggests that this difference is likely due to random variability rather than a meaningful distinction between the two shipping modes so we fail to reject H0.

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='ship_mode', y='profit', data=selected_data)
plt.title('Box Plot of Profits for Different Ship Modes')
plt.xlabel('Ship Mode')
plt.ylabel('Profit')
# Out:
# Text(0, 0.5, 'Profit')

# %%
from scipy.stats import f_oneway

ship_modes = df['ship_mode'].unique()
data_for_anova = [df[df['ship_mode'] == mode]['profit'] for mode in ship_modes]

test_statistic, pvalue = f_oneway(*data_for_anova)

print(f'Test Statistic: {test_statistic}')
print(f'P-value: {pvalue}')
# Out:
# Test Statistic: 0.20668658025016268
# P-value: 0.8132779836356978

# %% [markdown]
# ## Interpretation:
# The ANOVA test results suggest that there is no statistically significant difference in the mean profits across different ship modes. The low test statistic and high p-value indicate that the variation in profits can be attributed to random chance rather than a meaningful distinction between the ship modes so we fail to reject H0.

# %%
plt.figure(figsize=(12, 8))
sns.boxplot(x='ship_mode', y='profit', data=df)
plt.title('Box Plot of Profits Across Ship Modes')
plt.xlabel('Ship Mode')
plt.ylabel('Profit')

plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.histplot(data=df, x='profit', hue='ship_mode', multiple='stack', bins=20, edgecolor='black')
plt.title('Histogram of Profits Across Ship Modes')
plt.xlabel('Profit')
plt.ylabel('Count')

plt.show()
